# %%
# !pip install selenium

# %%
# importing librarys 
import selenium
import pandas as pd 
from selenium import webdriver
import warnings 
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By 
import time

# %%
# connecting to chrome driver 
driver = webdriver.Chrome(r"C:\Users\ganes\Downloads\Internship_assignment\Chrome_Driver\chromedriver_win32\chromedriver.exe")

# %% [markdown]
# Question1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.

# %%
# oping naukari.com by automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# entering designation and location as per Question 
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location = driver.find_element(By.XPATH,'/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input')
location.send_keys('Banglore')

# %%
search = driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
job_title = []
job_location = []
company_name = []
experience_required = []

# %%
# scraping job title_tag from page 
title_tag = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tag[0:10]:
    title=i.text
    job_title.append(title)

# scraping job location from the given page 
location_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location=i.text
    job_location.append(location)
    
# scraping company name from the given page 
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company=i.text
    company_name.append(company)
    
# scraping experience from given page 
experience_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tag[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
list_no=list(range(1,11))

# %%
# To fetch the url 
url=[]
url = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in url[0:11]:
    URL=i.get_attribute('href')
    url.append(URL)
url
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="f68c50669feee44fcc67856f01426812", element="CC1AB5464078173FDD1B0AD2DCF69A32_element_125")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f68c50669feee44fcc67856f01426812", element="CC1AB5464078173FDD1B0AD2DCF69A32_element_126")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f68c50669feee44fcc67856f01426812", element="CC1AB5464078173FDD1B0AD2DCF69A32_element_127")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f68c50669feee44fcc67856f01426812", element="CC1AB5464078173FDD1B0AD2DCF69A32_element_128")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f68c50669feee44fcc67856f01426812", element="CC1AB5464078173FDD1B0AD2DCF69A32_element_129")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="f68c50669feee44fcc67856f01426812", element="CC1AB5464078173FDD1B0AD2DCF69A32_element_130")>,
# ...

# %%
Url=url[-11:-1]
len(Url)
# Out:
# 10

# %%
import pandas as pd
df = pd.DataFrame({'List No':list_no,'Title':job_title,'Location':job_location,'Company_Name':company_name,'Experience':experience_required,'URL':Url})
df
# Out:
#    List No                              Title  \
# 0        1                  Tech Data Analyst
# 1        2                       Data Analyst
# 2        3                       Data Analyst
# 3        4               Insight Data Analyst
# 4        5                       Data Analyst
# 5        6                       Data Analyst
# 6        7                       Data Analyst
# 7        8  Celonis & Salesforce Data Analyst
# 8        9  Celonis & Salesforce Data Analyst
# 9       10                       Data Analyst
#
#                                             Location  \
# 0  Hybrid - Gurgaon/ Gurugram, Haryana, Bangalore...
# 1  Kolkata, Hyderabad/Secunderabad, Pune, Chennai...
# 2                    Bangalore/ Bengaluru, Karnataka
# 3  Noida, Uttar Pradesh, Bangalore/ Bengaluru, Ka...
# 4  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 5                                Bangalore/Bengaluru
# 6                       Chennai, Bangalore/Bengaluru
# ...

# %%
# To scraping data on multiple pages
start=0
end=5
job_title=[]
for page in range(start,end):
    title_tag = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
    for i in title_tag[0:10]:
        title=i.text
        job_title.append(title)
    next_button=driver.find_element(By.XPATH,'//a[@class="fright fs14 btn-secondary br2"]')
    next_button.click()
    time.sleep(3)

# %%
len(job_title)
# Out:
# 50

# %%
Question2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.

# %%
# oping naukari.com by automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# entering designation and location as per Question 
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location = driver.find_element(By.XPATH,'/html/body/div[1]/div[7]/div/div/div[5]/div/div/div/div[1]/div/input')
location.send_keys('Banglore')

# %%
search = driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
job_title = []
job_location = []
company_name = []
experience_required = []

# %%
# scraping job title_tag from page 
title_tag = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tag[0:10]:
    title=i.text
    job_title.append(title)

# scraping job location from the given page 
location_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location=i.text
    job_location.append(location)
    
# scraping company name from the given page 
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company=i.text
    company_name.append(company)
    
# scraping experience from given page 
experience_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tag[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
list_no=list(range(1,11))

# %%
# To fetch the url 
url=[]
url = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in url[0:11]:
    URL=i.get_attribute('href')
    url.append(URL)
url
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="09441675eaa38e817389156bd389a158", element="FCE8219C810D8DC659E694DABCA5A879_element_405")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="09441675eaa38e817389156bd389a158", element="FCE8219C810D8DC659E694DABCA5A879_element_406")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="09441675eaa38e817389156bd389a158", element="FCE8219C810D8DC659E694DABCA5A879_element_407")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="09441675eaa38e817389156bd389a158", element="FCE8219C810D8DC659E694DABCA5A879_element_408")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="09441675eaa38e817389156bd389a158", element="FCE8219C810D8DC659E694DABCA5A879_element_409")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="09441675eaa38e817389156bd389a158", element="FCE8219C810D8DC659E694DABCA5A879_element_410")>,
# ...

# %%
Url=url[-11:-1]
len(Url)
# Out:
# 10

# %%
import pandas as pd
df = pd.DataFrame({'List No':list_no,'Title':job_title,'Location':job_location,'Company_Name':company_name,'Experience':experience_required,'URL':Url})
df
# Out:
#    List No                                              Title  \
# 0        1  Permanent Opportunity - Data Scientist(Snaplog...
# 1        2                   Analystics & Modeling Specialist
# 2        3                    Machine Learning (AI) Architect
# 3        4                               Staff Data Scientist
# 4        5                                     Data Scientist
# 5        6                              Senior Data Scientist
# 6        7                                     Data Scientist
# 7        8                          Hiring For Data Scientist
# 8        9                                     Data Scientist
# 9       10                                     Data Scientist
#
#                                             Location  \
# 0  Hybrid - Kolkata, Hyderabad/Secunderabad, Pune...
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 2  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 3                                Bangalore/Bengaluru
# ...

# %%
# To scraping data on multiple pages
start=0
end=5
job_title=[]
for page in range(start,end):
    title_tag = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
    for i in title_tag[0:10]:
        title=i.text
        job_title.append(title)
    next_button=driver.find_element(By.XPATH,'//a[@class="fright fs14 btn-secondary br2"]')
    next_button.click()
    time.sleep(3)
len(job_title)
# Out:
# 50

# %% [markdown]
# Question3: In this question you have to scrape data using the filters available on the webpage
#   You have to use the location and salary filter.

# %%
# oping naukari.com by automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# entering designation and location as per Question 
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
search = driver.find_element(By.CLASS_NAME,'qsbSubmit')
search.click()

# %%
# select salary checkbox 3-6 lac
checkbox = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[2]/div[2]/div[2]/label/i')
checkbox.click()

# %%
# select location checkbox dehli-ncr
checkbox = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i')
checkbox.click()

# %%
job_title = []
job_location = []
company_name = []
experience_required = []

# %%
# scraping job title_tag from page 
title_tag = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tag[0:10]:
    title=i.text
    job_title.append(title)

# scraping job location from the given page 
location_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tag[0:10]:
    location=i.text
    job_location.append(location)
    
# scraping company name from the given page 
company_tag = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company=i.text
    company_name.append(company)
    
# scraping experience from given page 
experience_tag = driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tag[0:10]:
    experience=i.text
    experience_required.append(experience)

# To fetch the url 
url=[]
url = driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in url[0:11]:
    URL=i.get_attribute('href')
    url.append(URL)
Url=url[-11:-1]
len(Url)
# Out:
# 10

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd
df = pd.DataFrame({'List No':list_no,'Title':job_title,'Location':job_location,'Company_Name':company_name,'Experience':experience_required,'URL':Url})
df
# Out:
#    List No                   Title  \
# 0        1   Junior Data Scientist
# 1        2          Data Scientist
# 2        3          Data Scientist
# 3        4          Data Scientist
# 4        5   Python and ML Trainer
# 5        6          Data Scientist
# 6        7                  Intern
# 7        8          Data Scientist
# 8        9  Lead Assistant Manager
# 9       10   Junior Data Scientist
#
#                                             Location  \
# 0  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 1              Gurgaon/Gurugram, Bangalore/Bengaluru
# 2                                              Noida
# 3  Kolkata, Mumbai, New Delhi, Hyderabad/Secunder...
# 4  Hyderabad/Secunderabad, New Delhi, Pune, Gurga...
# 5                                        Delhi / NCR
# 6                                   Gurgaon/Gurugram
# 7                                              Noida
# 8                                   Gurgaon/Gurugram
# ...

# %%
Question 4: Scrape data of first 100 sunglasses listings on flipkart.com .

# %%
# oping flipkart.com by automated chrome browser
driver.get('http://www.flipkart.com/')

# %%
# entering search for products, brands and more as per Question 
designation = driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys('sunglasses')

# %%
search = driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
# click checkbox of flipkart Assured 
checkbox = driver.find_element(By.XPATH,'//section[@class="_2hbLCH _24gLJx"]')
checkbox.click()

# %%
brand_name=[]
product_des=[]
price=[]

while len(brand_name)<100:
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)
    
    # scraping Brand name from page 
    brand_na = driver.find_elements(By.CLASS_NAME,'_2WkVRV')
    for i in brand_na[0:41]:
        brand=i.text
        brand_name.append(brand)
    

    # scraping Product Description from page 
    product_de = driver.find_elements(By.CLASS_NAME,'IRpwTa')
    for i in product_de[0:41]:
        product=i.text
        product_des.append(product)
   

    # scraping Price from page 
    pric = driver.find_elements(By.CLASS_NAME,'_30jeq3')
    for i in pric[0:41]:
        pri=i.text
        price.append(pri)

print(len(brand_name),len(product_des),len(price))
# Out:
# 120 120 120

# %%
list_no=list(range(1,121))

# %%
import pandas as pd
df = pd.DataFrame({'List No':list_no,'Brand Name':brand_name,'Product Description':product_des,'Price':price})
df
# Out:
#      List No    Brand Name                                Product Description  \
# 0          1        GANSTA    Gradient, UV Protection Aviator Sunglasses (57)
# 1          2        PIRASO              UV Protection Aviator Sunglasses (58)
# 2          3      Fastrack       UV Protection Aviator Sunglasses (Free Size)
# 3          4  hayden haiza              UV Protection Cat-eye Sunglasses (39)
# 4          5         NuVew              UV Protection Aviator Sunglasses (57)
# ..       ...           ...                                                ...
# 115      116        AISLIN  Toughened Glass Lens, UV Protection Aviator Su...
# 116      117     Elligator             UV Protection Wayfarer Sunglasses (53)
# 117      118  CRYSTAL CART  Mirrored, Night Vision Oval Sunglasses (Free S...
# 118      119        OAKLEY                   Latch Beta Retro Square Sunglass
# 119      120  LOUIS KOUROS  UV Protection, Riding Glasses, Gradient, Mirro...
#
#       Price
# 0      ₹311
# ...

# %%
# 100 sunglasses record 
df.head(-20)
# Out:
#     List No     Brand Name                                Product Description  \
# 0         1         GANSTA    Gradient, UV Protection Aviator Sunglasses (57)
# 1         2         PIRASO              UV Protection Aviator Sunglasses (58)
# 2         3       Fastrack       UV Protection Aviator Sunglasses (Free Size)
# 3         4   hayden haiza              UV Protection Cat-eye Sunglasses (39)
# 4         5          NuVew              UV Protection Aviator Sunglasses (57)
# ..      ...            ...                                                ...
# 95       96      ROYAL SON  Polarized, UV Protection Wayfarer Sunglasses (61)
# 96       97  VINCENT CHASE  Polarized, UV Protection Wayfarer Sunglasses (49)
# 97       98         OAKLEY                               Rectangular Sunglass
# 98       99    PETER JONES  UV Protection, Gradient Retro Square Sunglasse...
# 99      100     style guru  Mirrored, Night Vision, UV Protection Wayfarer...
#
#      Price
# 0     ₹311
# ...

# %% [markdown]
# Question 5: Scrape 100 reviews data from flipkart.com for iphone11 phone.

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART')

# %%
rating=[]
review_summary=[]
full_review=[]


ratin = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in ratin:
    rati=i.text
    rating.append(rati)      
review_summar = driver.find_elements(By.CLASS_NAME,'_2-N8zT')
for i in review_summar:
    review_summa=i.text
    review_summary.append(review_summa)               
full_revie = driver.find_elements(By.CLASS_NAME,'t-ZTKy')
for i in full_revie:
    full_revi=i.text
    full_review.append(full_revi) 
                   
next_click=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]').click()
time.sleep(3)

ratin = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
for i in ratin:
    rati=i.text
    rating.append(rati)      
review_summar = driver.find_elements(By.CLASS_NAME,'_2-N8zT')
for i in review_summar:
    review_summa=i.text
    review_summary.append(review_summa)               
full_revie = driver.find_elements(By.CLASS_NAME,'t-ZTKy')
for i in full_revie:
    full_revi=i.text
    full_review.append(full_revi)

# %%
for i in list(range(0,8)):
    next_click=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[12]').click()
    time.sleep(3)
    ratin = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in ratin:
        rati=i.text
        rating.append(rati)      
    review_summar = driver.find_elements(By.CLASS_NAME,'_2-N8zT')
    for i in review_summar:
        review_summa=i.text
        review_summary.append(review_summa)               
    full_revie = driver.find_elements(By.CLASS_NAME,'t-ZTKy')
    for i in full_revie:
        full_revi=i.text
        full_review.append(full_revi)

# %%
print(len(rating),len(review_summary),len(full_review))
# Out:
# 97 100 100

# %%
# from different class negative review 
rating.insert(60,1)
rating.insert(62,1)
rating.insert(90,1)

# %%
list_no=list(range(1,101))

# %%
import pandas as pd
df = pd.DataFrame({'List No':list_no,'Rating':rating,'Review Summary':review_summary,'Full Review':full_review})
df
# Out:
#     List No Rating        Review Summary  \
# 0         1      5        Simply awesome
# 1         2      5      Perfect product!
# 2         3      5   Best in the market!
# 3         4      4       Value-for-money
# 4         5      5    Highly recommended
# ..      ...    ...                   ...
# 95       96      5     Terrific purchase
# 96       97      4  Good quality product
# 97       98      5             Wonderful
# 98       99      5              Terrific
# 99      100      5   Best in the market!
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  finally an iPhone with very nice battery backu...
# ...

# %% [markdown]
# Question6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.

# %%
driver.get('http://www.flipkart.com/')

# %%
designation = driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys('sneakers')

# %%
search = driver.find_element(By.CLASS_NAME,'L0Z3Pu')
search.click()

# %%
# click checkbox of flipkart Assured 
checkbox = driver.find_element(By.XPATH,'//section[@class="_2hbLCH _24gLJx"]')
checkbox.click()

# %%
brand_name=[]
product_des=[]
price=[]

while len(brand_name)<100:
    next_button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)
    
    # scraping Brand name from page 
    brand_na = driver.find_elements(By.CLASS_NAME,'_2WkVRV')
    for i in brand_na[0:41]:
        brand=i.text
        brand_name.append(brand)
    

    # scraping Product Description from page 
    product_de = driver.find_elements(By.CLASS_NAME,'IRpwTa')
    for i in product_de[0:41]:
        product=i.text
        product_des.append(product)
   

    # scraping Price from page 
    pric = driver.find_elements(By.CLASS_NAME,'_30jeq3')
    for i in pric[0:41]:
        pri=i.text
        price.append(pri)

print(len(brand_name),len(product_des),len(price))
# Out:
# 120 120 120

# %%
list_no=list(range(1,121))

# %%
df = pd.DataFrame({'List No':list_no,'Brand Name':brand_name,'Product Description':product_des,'Price':price})
df
# Out:
#      List No           Brand Name  \
# 0          1                BIRDE
# 1          2               BRUTON
# 2          3                 aadi
# 3          4              LIBERTY
# 4          5  World Wear Footwear
# ..       ...                  ...
# 115      116                 PUMA
# 116      117                asian
# 117      118               REEBOK
# 118      119            ROCKFIELD
# 119      120                Sparx
#
#                                    Product Description   Price
# 0        Combo Pack of 2 Casual Shoes Sneakers For Men    ₹579
# 1    Men Combo Pack of 2 Sports Shoes & Casual Snea...    ₹369
# 2                                     Sneakers For Men    ₹349
# 3                             JUMP-02 Sneakers For Men    ₹329
# 4    Latest Exclusive Affordable Collection of Tren...    ₹249
# ..                                                 ...     ...
# 115                       X-Ray Speed Sneakers For Men  ₹3,359
# ...

# %%
df.head(-20)
# Out:
#     List No           Brand Name  \
# 0         1                BIRDE
# 1         2               BRUTON
# 2         3                 aadi
# 3         4              LIBERTY
# 4         5  World Wear Footwear
# ..      ...                  ...
# 95       96             Skechers
# 96       97         Jack Diamond
# 97       98       KNIGHT WALKERS
# 98       99                 PUMA
# 99      100                 FILA
#
#                                   Product Description   Price
# 0       Combo Pack of 2 Casual Shoes Sneakers For Men    ₹579
# 1   Men Combo Pack of 2 Sports Shoes & Casual Snea...    ₹369
# 2                                    Sneakers For Men    ₹349
# 3                            JUMP-02 Sneakers For Men    ₹329
# 4   Latest Exclusive Affordable Collection of Tren...    ₹249
# ..                                                ...     ...
# 95              UNO - NIGHT SHADES Sneakers For Women  ₹3,849
# ...

# %% [markdown]
# Question 7: Go to webpage https://www.amazon.in/ scrape first 10 laptops data.

# %%
driver.get('https://www.amazon.in/')

# %%
designation = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
designation.send_keys('Laptop')

# %%
search = driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
# for i7 checkbox 
checkbox = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/span[9]/li/span/a/div/label/i')
checkbox.click()

# %%
# for above 1 star 
checkbox = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[3]/ul/span[4]/li/span/a/section/i')
checkbox.click()

# %%
title=[]
rating=[]
price=[]
    
# scraping title name from page 
titl = driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in titl[0:10]:
    tit=i.text
    title.append(tit)
    
# scraping ratings from page 
ratin = driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]/span')
for i in ratin[0:10]:
    rati=i.get_attribute('aria-label')
    rating.append(rati)
    
# scraping Price from page 
pric = driver.find_elements(By.CLASS_NAME,'a-price-whole')
for i in pric[0:10]:
    pri=i.text
    price.append(pri)

print(len(title),len(rating),len(price))
# Out:
# 10 10 10

# %%
list_no=list(range(1,11))

# %%
df = pd.DataFrame({'List No':list_no,'Title':title,'Rating':rating,'Price':price})
df
# Out:
#    List No                                              Title  \
# 0        1  Acer Predator Helios Neo 16 Gaming Laptop 13th...
# 1        2  Lenovo ThinkPad E14 Intel Core i7 12th Gen 14"...
# 2        3  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...
# 3        4  ASUS TUF Gaming F15 (2023) 90WHr Battery, Inte...
# 4        5  HP Envy x360 12th Gen Intel Core i7-13.3 inch(...
# 5        6  HP Victus Gaming Latest 12th Gen Intel Core i7...
# 6        7  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...
# 7        8  Samsung Galaxy Book2 360 Intel 12th Gen i7 Evo...
# 8        9  ASUS TUF Gaming F15 (2022), 15.6"(39.62 cms) F...
# 9       10  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...
#
#                Rating     Price
# 0  4.4 out of 5 stars  1,29,990
# 1                   6    98,990
# 2  3.8 out of 5 stars    79,990
# 3                  18  1,15,990
# 4  4.4 out of 5 stars  1,03,990
# 5                  68  1,01,278
# 6  5.0 out of 5 stars    84,999
# ...

# %%
Question 8: Write a python program to scrape data for Top 1000 Quotes of All Time.

# %%
driver.get('https://www.azquotes.com/')

# %%
top_quotes = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
top_quotes.click()

# %%
Quote = []
Author = []
type_of_quotes = []

while len(Quote)<1000:
    # scraping Quote name from page 
    Quot = driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in Quot:
        Quo=i.text
        Quote.append(Quo)

    # scraping Author from page 
    Autho = driver.find_elements(By.XPATH,'//div[@class="author"]')
    for i in Autho:
        Auth=i.text
        Author.append(Auth)

    # scraping type_of_quotes from page 
    type_of_quote = driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in type_of_quote:
        type_of_quot=i.text
        type_of_quotes.append(type_of_quot)
    if len(Quote)==1000:
        break
   
    next_click=driver.find_element(By.XPATH,'//li[@class="next"]').click()
    time.sleep(3)
        
print(len(Quote),len(Author),len(type_of_quotes))
# Out:
# 1000 1000 1000

# %%
list_no=list(range(1,1001))

# %%
df = pd.DataFrame({'List No':list_no,'Quote':Quote,'Author':Author,'Type Of Quotes':type_of_quotes})
df
# Out:
#      List No                                              Quote  \
# 0          1  The essence of strategy is choosing what not t...
# 1          2  One cannot and must not try to erase the past ...
# 2          3  Patriotism means to stand by the country. It d...
# 3          4  Death is something inevitable. When a man has ...
# 4          5  You have to love a nation that celebrates its ...
# ..       ...                                                ...
# 995      996  Regret for the things we did can be tempered b...
# 996      997  America... just a nation of two hundred millio...
# 997      998  For every disciplined effort there is a multip...
# 998      999  The spiritual journey is individual, highly pe...
# 999     1000  The mind is not a vessel to be filled but a fi...
#
#                  Author                            Type Of Quotes
# 0        Michael Porter  Essence, Deep Thought, Transcendentalism
# ...

# %% [markdown]
# Question 9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,
# Term of office, Remarks) from https://www.jagranjosh.com/.

# %%
driver.get('https://www.jagranjosh.com/')

# %%
# select GK option
checkbox = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/div[1]/div/div[5]/div/div[1]/header/div[3]/ul/li[3]/a')
checkbox.click()

# %%
# select List of all Prime Ministers of India. 
checkbox = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
checkbox.click()

# %%
rows=[]
rows = len(driver.find_elements(By.XPATH,
    "/html/body/div[1]/div[2]/div/div[2]/div/div[2]/div/div/div/div[4]/span/div[4]/table/tbody/tr"))
rows
# Out:
# 20

# %%
cols=[]
cols = len(driver.find_elements(By.XPATH,
    "/html/body/div[1]/div[2]/div/div[2]/div/div[2]/div/div/div/div[4]/span/div[4]/table/tbody/tr/td"))
cols
# Out:
# 95

# %%
for r in range(2, rows+1):
    for p in range(1, cols+1):
       
        # obtaining the text from each column of the table
        value = driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div/div[2]/div/div[2]/div/div/div/div[4]/span/div[4]/table/tbody/tr["+str(r)+"]/td["+str(p)+"]/p")
        for item in value:
            print(item.text, end='       ')
# Out:
# 1.       Jawahar Lal Nehru       (1889–1964)       15 August 1947 to 27 May 1964       16 years, 286 days       The first prime minister of India and the longest-serving PM of India, the first to die in office.       2.       Gulzarilal Nanda (Acting)       (1898-1998)       27 May 1964 to 9 June 1964,       13 days       First acting PM of India       3.       Lal Bahadur Shastri       (1904–1966)       9 June 1964 to 11 January 1966       1 year, 216 days       He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965       4.        Gulzari Lal Nanda  (Acting)       (1898-1998)       11 January 1966 to 24 January 1966       13 days       -       5.       Indira Gandhi       (1917–1984)       24 January 1966 to 24 March 1977       11 years, 59 days       First female Prime Minister of India       6.       Morarji Desai       (1896–1995)       24 March 1977 to  28 July 1979        2 year, 126 days       Oldest to become PM (81 years old) and first to resign fr
# ...

# %%
data=[]
for r in range(2, rows+1):
    for p in range(1, cols+1):
       
        # obtaining the text from each column of the table
        value = driver.find_elements(By.XPATH,"/html/body/div[1]/div[2]/div/div[2]/div/div[2]/div/div/div/div[4]/span/div[4]/table/tbody/tr["+str(r)+"]/td["+str(p)+"]/p")
        for item in value:
            data.append(item.text)

# %%
s_n=[]
Name=[]
Born_Dead=[]
start_Term_of_office=[]
end_Term_of_office=[]
Remark=[]
i=1
a=0
for item in data:
    
    a=a+1
    if i==1:
        s_n.append(item) 
    elif i==2:
        Name.append(item)
    elif i==3:
        Born_Dead.append(item)
    elif i==4:
        start_Term_of_office.append(item)            
    elif i==5:
        end_Term_of_office.append(item)
    elif i==6:
        Remark.append(item)
        i=0
    
    i=i+1

# %%
data[0:20]
# Out:
# ['1.',
#  'Jawahar Lal Nehru',
#  '(1889–1964)',
#  '15 August 1947 to 27 May 1964',
#  '16 years, 286 days',
#  'The first prime minister of India and the longest-serving PM of India, the first to die in office.',
#  '2.',
#  'Gulzarilal Nanda (Acting)',
#  '(1898-1998)',
#  '27 May 1964 to 9 June 1964,',
#  '13 days',
#  'First acting PM of India',
#  '3.',
#  'Lal Bahadur Shastri',
#  '(1904–1966)',
#  '9 June 1964 to 11 January 1966',
#  '1 year, 216 days',
#  "He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965",
#  '4. ',
#  'Gulzari Lal Nanda  (Acting)']

# %%
s_n[0:5]
# Out:
# ['1.', '2.', '3.', '4. ', '5.']

# %%
Name[0:5]
# Out:
# ['Jawahar Lal Nehru',
#  'Gulzarilal Nanda (Acting)',
#  'Lal Bahadur Shastri',
#  'Gulzari Lal Nanda  (Acting)',
#  'Indira Gandhi']

# %%
Born_Dead[0:5]
# Out:
# ['(1889–1964)', '(1898-1998)', '(1904–1966)', '(1898-1998)', '(1917–1984)']

# %%
start_Term_of_office[0:5]
# Out:
# ['15 August 1947 to 27 May 1964',
#  '27 May 1964 to 9 June 1964,',
#  '9 June 1964 to 11 January 1966',
#  '11 January 1966 to 24 January 1966',
#  '24 January 1966 to 24 March 1977']

# %%
end_Term_of_office[0:5]
# Out:
# ['16 years, 286 days',
#  '13 days',
#  '1 year, 216 days',
#  '13 days',
#  '11 years, 59 days']

# %%
Remark[0:5]
# Out:
# ['The first prime minister of India and the longest-serving PM of India, the first to die in office.',
#  'First acting PM of India',
#  "He has given the slogan of 'Jai Jawan Jai Kisan' during the Indo-Pak war of 1965",
#  '-',
#  'First female Prime Minister of India']

# %%
len(data)
# Out:
# 114

# %%
df = pd.DataFrame({'S.N.':s_n,'Name':Name,'Born Dead':Born_Dead,'start_Term_of_office':start_Term_of_office,'end_Term_of_office':end_Term_of_office,'Remark':Remark})
df
# Out:
#    S.N.                         Name     Born Dead  \
# 0    1.            Jawahar Lal Nehru   (1889–1964)
# 1    2.    Gulzarilal Nanda (Acting)   (1898-1998)
# 2    3.          Lal Bahadur Shastri   (1904–1966)
# 3   4.   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4    5.                Indira Gandhi   (1917–1984)
# 5    6.                Morarji Desai   (1896–1995)
# 6    7.                 Charan Singh   (1902–1987)
# 7    8.                Indira Gandhi   (1917–1984)
# 8    9.                 Rajiv Gandhi   (1944–1991)
# 9   10.                  V. P. Singh   (1931–2008)
# 10  11.              Chandra Shekhar   (1927–2007)
# 11  12.          P. V. Narasimha Rao   (1921–2004)
# 12  13.         Atal Bihari Vajpayee  (1924- 2018)
# 13  14.             H. D. Deve Gowda   (born 1933)
# 14  15.           Inder Kumar Gujral   (1919–2012)
# 15  16.         Atal Bihari Vajpayee   (1924-2018)
# 16  17.               Manmohan Singh   (born 1932)
# ...

# %% [markdown]
# Question 10: Write a python program to display list of 50 Most expensive cars in the world (i.e.
# Car name and Price) from https://www.motor1.com/

# %%
driver.get('https://www.motor1.com/')

# %%
designation = driver.find_element(By.XPATH,'//input[@class="m1-search-panel-input m1-search-form-text"]')
designation.send_keys('50 most expensive car')

# %%
search = driver.find_element(By.XPATH,'//button[@class="m1-search-panel-button m1-search-form-button-animate icon-search-svg"]')
search.click()

# %%
search = driver.find_element(By.XPATH,'/html/body/div[3]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/a')
search.click()

# %%
Name=[]
price=[]

# scraping name from page 
Nam = driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in Nam:
    Na=i.text
    Name.append(Na)
    
# scraping Price from page 
pric = driver.find_elements(By.XPATH,'/html/body/div[2]/div[7]/div[2]/div[1]/div[2]/div[1]/p/strong')
for i in pric:
    pri=i.text
    price.append(pri)

print(len(Name),len(price))
# Out:
# 51 51

# %%
# removing unnecessary element
print(len(Name),len(price))
# Out:
# 50 50

# %%
list_no=list(range(1,51))

# %%
df = pd.DataFrame({'List No':list_no,'Name':Name,'Price':price})
df
# Out:
#     List No                             Name                        Price
# 0         1                    De Tomaso P72          Price: $1.3 Million
# 1         2                Ferrari LaFerrari          Price: $1.4 Million
# 2         3                    Pagani Huayra          Price: $1.4 Million
# 3         4                     McLaren Elva          Price: $1.7 Million
# 4         5                      Czinger 21C          Price: $1.7 Million
# 5         6                    Ferrari Monza          Price: $1.7 Million
# 6         7               Gordon Murray T.33          Price: $1.7 Million
# 7         8                Koenigsegg Gemera          Price: $1.7 Million
# 8         9                      Zenvo TSR-S          Price: $1.7 Million
# 9        10               Hennessey Venom F5          Price: $1.8 Million
# 10       11                  Bentley Bacalar          Price: $1.9 Million
# 11       12    Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# ...
